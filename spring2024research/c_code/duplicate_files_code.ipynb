# %%
import os
import shutil
from ParameterDistributions import *
from HaloParameters import *

halo_masses = [39810717100, 251188643000, 79432823500, 251188643000, 
               199526231000, 125892541000, 125892541000, 125892541000, 
               158489319000, 158489319000, 316227766000, 50118723400, 
               199526231000, 79432823500, 316227766000, 251188643000, 
               100000000000, 79432823500, 199526231000, 251188643000, 
               398107171000, 63095734400, 63095734400, 398107171000, 
               50118723400, 19952623100, 251188643000, 125892541000, 
               15848931900, 31622776600, 50118723400, 79432823500, 
               199526231000, 158489319000, 501187234000, 100000000000, 
               199526231000, 100000000000, 158489319000, 79432823500, 
               316227766000, 63095734400, 39810717100, 316227766000, 
               63095734400, 39810717100, 158489319000, 79432823500, 
               100000000000, 79432823500, 79432823500, 316227766000, 
               125892541000, 125892541000, 398107171000, 100000000000, 
               63095734400, 79432823500, 199526231000, 199526231000, 
               199526231000, 630957344000, 25118864300, 158489319000, 
               125892541000, 31622776600, 39810717100, 125892541000, 
               31622776600, 251188643000, 199526231000, 100000000000, 
               794328235000, 125892541000, 79432823500, 199526231000, 
               199526231000, 158489319000, 158489319000, 158489319000, 
               100000000000, 630957344000, 501187234000, 199526231000, 50118723400, 158489319000, 398107171000, 125892541000, 39810717100, 63095734400, 398107171000, 63095734400, 251188643000, 398107171000, 199526231000, 630957344000, 398107171000, 199526231000, 316227766000, 316227766000]

# Define the original file and the directory where it is located
original_file = 'additional_forces.c'
# directory = 'home/vk9342/spring2024research/'

#iterate over every combination of params
i = 0
for i in range (20, len(halo_masses)):
    rho0 = rho_0_func(halo_masses[i])
    r0 = r_0_func(halo_masses[i])
    
    rho0_rounded = round(rho0, 2)
    r0_rounded = round(r0, 2)

    print(rho0)
    print(r0)
    
    # Define the variations for the new file names
    new_file_variations = ('additional_forces_rho0'+str(rho0_rounded)+'_r0'+str(r0_rounded)+'.c')
    # Read the content of the original file
    # with open(os.path.join(directory, original_file), 'r') as file:
    with open(original_file, 'r') as file:
        content = file.read()
    
    # Write the content to new files with the different names
    new_file_path = (new_file_variations)
    with open(new_file_path, 'w') as file:
        file.write(content)
    
    print(f"Created {len(new_file_variations)} new files with variations in names.")

# %% [markdown]
# # Change value in c file

# %%
import os
import shutil
from ParameterDistributions import *
from HaloParameters import *

halo_masses = [39810717100, 251188643000, 79432823500, 251188643000, 
               199526231000, 125892541000, 125892541000, 125892541000, 
               158489319000, 158489319000, 316227766000, 50118723400, 
               199526231000, 79432823500, 316227766000, 251188643000, 
               100000000000, 79432823500, 199526231000, 251188643000, 
               398107171000, 63095734400, 63095734400, 398107171000, 
               50118723400, 19952623100, 251188643000, 125892541000, 
               15848931900, 31622776600, 50118723400, 79432823500, 
               199526231000, 158489319000, 501187234000, 100000000000, 
               199526231000, 100000000000, 158489319000, 79432823500, 
               316227766000, 63095734400, 39810717100, 316227766000, 
               63095734400, 39810717100, 158489319000, 79432823500, 
               100000000000, 79432823500, 79432823500, 316227766000, 
               125892541000, 125892541000, 398107171000, 100000000000, 
               63095734400, 79432823500, 199526231000, 199526231000, 
               199526231000, 630957344000, 25118864300, 158489319000, 
               125892541000, 31622776600, 39810717100, 125892541000, 
               31622776600, 251188643000, 199526231000, 100000000000, 
               794328235000, 125892541000, 79432823500, 199526231000, 
               199526231000, 158489319000, 158489319000, 158489319000, 
               100000000000, 630957344000, 501187234000, 199526231000, 
               50118723400, 158489319000, 398107171000, 125892541000, 
               39810717100, 63095734400, 398107171000, 63095734400, 
               251188643000, 398107171000, 199526231000, 630957344000, 
               398107171000, 199526231000, 316227766000, 316227766000]

# Define the original file and the directory where it is located
original_file = 'additional_forces.c'

#iterate over every combination of params
i = 0
for i in range (1):
#     rho0 = rho_0_func(halo_masses[i])
#     r0 = r_0_func(halo_masses[i])
    
#     rho0_rounded = round(rho0, 2)
#     r0_rounded = round(r0, 2)
    rho0_rounded = 7.44
    r0_rounded = 23.08

    print(f"rho0: {rho0_rounded}, r0: {r0_rounded}")
    
    # Define the variations for the new file names
    new_file_name = f'additional_forces_rho0{rho0_rounded}_r0{r0_rounded}.c'
    
    # Read the content of the original file
    with open(original_file, 'r') as file:
        content = file.read()
    
    # Replace the placeholder line with the new values (modify according to your code structure)
    # Assuming you have a line in the original file like: `double rho0 = ...;` and `double r0 = ...;`
    modified_content = content.replace('double rho_0 = 25.82;', f'double rho_0 = {rho0_rounded};')
    modified_content = modified_content.replace('double r_0 = 8.89;', f'double r_0 = {r0_rounded};')
    
    # Write the modified content to new files with the different names
    new_file_path = new_file_name
    with open(new_file_path, 'w') as new_file:
        new_file.write(modified_content)
    
    print(f"Created {new_file_name} with rho0 = {rho0_rounded} and r0 = {r0_rounded}.")
# Out:
# rho0: 7.44, r0: 23.08
# Created additional_forces_rho07.44_r023.08.c with rho0 = 7.44 and r0 = 23.08.

# %%
halo_masses = [39810717100, 251188643000, 79432823500, 251188643000, 
               199526231000, 125892541000, 125892541000, 125892541000, 
               158489319000, 158489319000, 316227766000, 50118723400, 
               199526231000, 79432823500, 316227766000, 251188643000, 
               100000000000, 79432823500, 199526231000, 251188643000, 
               398107171000, 63095734400, 63095734400, 398107171000, 
               50118723400, 19952623100, 251188643000, 125892541000, 
               15848931900, 31622776600, 50118723400, 79432823500, 
               199526231000, 158489319000, 501187234000, 100000000000, 
               199526231000, 100000000000, 158489319000, 79432823500, 
               316227766000, 63095734400, 39810717100, 316227766000, 
               63095734400, 39810717100, 158489319000, 79432823500, 
               100000000000, 79432823500, 79432823500, 316227766000, 
               125892541000, 125892541000, 398107171000, 100000000000, 
               63095734400, 79432823500, 199526231000, 199526231000, 
               199526231000, 630957344000, 25118864300, 158489319000, 
               125892541000, 31622776600, 39810717100, 125892541000, 
               31622776600, 251188643000, 199526231000, 100000000000, 
               794328235000, 125892541000, 79432823500, 199526231000, 
               199526231000, 158489319000, 158489319000, 158489319000, 
               100000000000, 630957344000, 501187234000, 199526231000, 
               50118723400, 158489319000, 398107171000, 125892541000, 
               39810717100, 63095734400, 398107171000, 63095734400, 
               251188643000, 398107171000, 199526231000, 630957344000, 
               398107171000, 199526231000, 316227766000, 316227766000]

rho = []
r = []
for i in range (len(halo_masses)):
    rho0 = rho_0_func(halo_masses[i])
    r0 = r_0_func(halo_masses[i])
    
    rho0_rounded = round(rho0, 2)
    r0_rounded = round(r0, 2)
    rho.append(rho0_rounded)
    r.append(r0_rounded)


print (rho)
print (r)
# Out:
# [8.44, 6.51, 7.63, 6.51, 6.71, 7.14, 7.14, 7.14, 6.92, 6.92, 6.32, 8.16, 6.71, 7.63, 6.32, 6.51, 7.38, 7.63, 6.71, 6.51, 6.13, 7.88, 7.88, 6.13, 8.16, 9.45, 6.51, 7.14, 9.78, 8.76, 8.16, 7.63, 6.71, 6.92, 5.98, 7.38, 6.71, 7.38, 6.92, 7.63, 6.32, 7.88, 8.44, 6.32, 7.88, 8.44, 6.92, 7.63, 7.38, 7.63, 7.63, 6.32, 7.14, 7.14, 6.13, 7.38, 7.88, 7.63, 6.71, 6.71, 6.71, 5.84, 9.1, 6.92, 7.14, 8.76, 8.44, 7.14, 8.76, 6.51, 6.71, 7.38, 5.7, 7.14, 7.63, 6.71, 6.71, 6.92, 6.92, 6.92, 7.38, 5.84, 5.98, 6.71, 8.16, 6.92, 6.13, 7.14, 8.44, 7.88, 6.13, 7.88, 6.51, 6.13, 6.71, 5.84, 6.13, 6.71, 6.32, 6.32]
# ...
