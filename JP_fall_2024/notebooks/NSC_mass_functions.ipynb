# %%
import numpy as np
import matplotlib as mpl
from matplotlib import cm
import matplotlib.pyplot as plt
from scipy import stats
from scipy.optimize import curve_fit
from scipy.stats import norm
import math
import statistics
from scipy.optimize import fsolve
##plt.rcParams['text.usetex'] = False
import matplotlib as mpl
mpl.rcParams['mathtext.fontset'] = 'cm'
mpl.rcParams['font.family'] = 'serif'
from gaussian_functions import *



## From: Nuclear star clusters
## Nadine Neumayer · Anil Seth · Torsten B ̈oker

## eq 1 section 6.2
def logMNSC_eq (logMstellar): 
    Mstellar = 10**logMstellar  # in solar masses
    logMNSC = 0.48 * np.log(Mstellar/10**9) + 6
    # logMNSC = 0.92 * np.log(Mstellar / 10**9) + 6.13
    return logMNSC

def MNSC_random_sample (logMstellar, n):
    mu = logMNSC_eq(logMstellar)
    sigma = 0.6 #???
    logsample_MNSC = np.random.normal(mu, sigma, n) #in pc
    sample_MNSC = 10**logsample_MNSC
    return sample_MNSC #in solar masses

# %%
# logMstellar = np.linspace (6, 11, 100)
## Plot of Re for range of Stellar values 
logMstellar = np.linspace(6, 11, 1000)
sigma = 0.6
logMNSC = logMNSC_eq(logMstellar)
plt.figure(figsize = (5, 5))
plt.errorbar(logMstellar, logMNSC, yerr = sigma, color = 'green', ecolor = 'yellowgreen', alpha = 0.3)

plt.errorbar(logMstellar, 0.92 * np.log(10**logMstellar / 10**9) + 6.13, yerr = sigma, color = 'green', ecolor = 'yellowgreen', alpha = 0.3)
plt.xlabel('Log M Stellar')
plt.ylabel('log M NSC')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
