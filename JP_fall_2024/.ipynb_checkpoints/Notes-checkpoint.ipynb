# %% [markdown]
# # OCTOBER 22nd Tues
# probably going to blue line instead of red (screenshot)
# scott passed 8.3 not
# we could use ???, but they end at 10^9, blue things centered at 3.3 and red at 3, scot is sentered at 3
# instead go to 8.5 where scotts mass size is measured and eddie points
# fix it so that at higher than scotts last physics I use the value at that point and scatter
# ![Screen Shot 2024-10-22 at 9.42.55 AM.png](attachment:cffed3d2-20e6-4fa3-af7f-1d0484a0ae0e.png)
#
#
# Use cluster values for a and b for Re relation
#
# ![Screen Shot 2024-10-22 at 9.43.48 AM.png](attachment:2b728f94-059a-4b2a-bc7f-267b8051c911.png)
#
# which data do we think we woulod like to compare to for a cuspy fraction: if we look at virgo look at early types; gwens paper had higher MGC for red points
# when using gwens points, try to fit to only red point ie virgo, red and blue circles only seem different below 10^8
# mainly compare w virgo, more concrete mass sizew
#
# ![Screen Shot 2024-10-29 at 4.23.45 PM.png](attachment:b3a64a79-be70-4666-b550-68a3b710e56b.png)
#
#
# 8.5 may be our sweet spot, because mass size gets complicated at 10^9, enough masses

# %% [markdown]
# add NSCs as dist<br>
# Each run pick a GC fraction in each of my mas bins, sample mass from this:<br>
# https://arxiv.org/pdf/2001.03626<br>
#
# look at fraction (w scatter) plot: if yes then <br>
# sample mass <br>
# ![Screen Shot 2024-10-31 at 10.21.34 AM.png](attachment:697fa1c0-3eb5-4eb1-adf9-2066cace2435.png)
#
# expect scatter to go up
#
# correlation between M GC and M NSC
#
# environment qs secondary
#
# possible we dont actually get back to the original dist we will be sampling from

# %% [markdown]
# # For oct 15th
# ## What to do about the GC distribution?
#
# ### Option 1:
# Leaman and van de Ven: https://arxiv.org/pdf/2112.05573 <br>
# On the link between nuclear star cluster and globular cluster system mass, nucleation fraction and environment <br>
#
# Section 2 (Data) mentions assigning masses form a log-normal GC mass function with mean and width (5.2, 0.7).  <br>
# Could we crease distribution: N(GCs) as a function of Mstar and then assign the masses from this distribution. <br>
# eqs 7 and 8
# Note: $M_{GC, total} = \eta M_{*, gal} = $ total mass of GCs (including NSC) (based on section 3.3 (eq 11)) <br>
#
# Dependence on the GC mass function - section 4.2.1 - But which GC mass function is most accurate? <br>
#
# GC mass dependance on host galaxy: section 4.2.3 under figure 4 <br>
#
# Also mentioned in section 4.3, but dont really understand
#
# **Get M GC tot:**
# - Section 2: Galaxy total GC system masses (𝑀𝐺𝐶,𝑡𝑜𝑡) are taken from Peng et al. (2006); Spitler & Forbes (2009); Harris et al. (2013); Baldassare et al. (2014); den Brok et al. (2014); Forbes et al. (2018); Fahrion et al. (2020b); Leaman et al. (2020); Fahrion et al. (2020a) and RSJ19. or all other samples the total mass in GCs are com- puted from the reported GC numbers (𝑁𝐺𝐶 ) assuming an average mass of 𝑀𝐺𝐶 = 4 × 105M⊙.
#
# - Section 2: Log-normal GC mass function with mean and width (5.2, 0.7)
#
# - Secrtion 4.2.3: Host-mass dependent variations in the GC mass function parameters as seen in e.g., Jordán et al. 2007: <br>
# https://iopscience.iop.org/article/10.1086/516840/pdf <br>
# in this paper: 3.2.1. Initial GC Mass Function
# - M GC tot equations 7 and 8??
#
# **Get N(GC)**
# - Section 2: Amorisco et al. (2018), Lim et al. (2018) and Prole et al. (2019) provided estimates of the number of GCs for ultra-diffuse (UDGs) and/or low surface brightness (LSB) galaxies in the Coma and Fornax clusters

# %% [markdown]
# Andre s Jordan  <br>
# THE ACS VIRGO CLUSTER SURVEY XVI. SELECTION PROCEDURE AND CATALOGS OF GLOBULAR CLUSTER CANDIDATES <br>
# https://iopscience.iop.org/article/10.1088/0067-0049/180/1/54/pdf <br>

# %% [markdown]
# ## Nov 14th
#
# For now:
#
# M GC total (without): 1%, 0.5 and 5 % scatter  of M stellar
#
# 50% of the  runs get a NSC - also about 1% with same spread
#
# Do for 10^8
# _____
#
# Naidine fig 12 -  M
#
# fig 3 - N

# %% [markdown]
# # Nov 25th
# make grid:  <br>
# 4 - 5 realizations   <br>
# Dense grid at least 4-5  <br>
# 6-6.5 looks like boundry so dense  <br>
# 10 points so 100 total?  <br>

# %% [markdown]
# # December 5th
# 6.2 - 6.8 should be more sampling  <br>
# between 6 and 7, maybe more in halo mass direction - at 3.4 re it seems to have an impact, will there be a gradient there? <br>
# looks like a diagonal plane - makes sesne  <br>
#
# draw params and interpolate between 1 and 0 - 1 being nucleated, non nucleated - nearest grid points that we have <br>
#
# for given stellar mass <br>
# for each of the three axis - we have a weight - multiply by weight - at 10**8 30% of things have GC mas of 6 and then collapse and then weight it, do cac in three directions<br>
#
# some sort of average of what we have<br>
#
# color points by iteration - fraction that has - probability between 0 and 1 - 10 iterations some might and some might not <br>
#
# could tag these points by average mass of cluster instead of binary yes no<br>
#
# showing both <br>
#
# bottom line plot needs to be nucleation function<br>
#
# or three lines for three thresholds when plotting <br>
#
# fraction easier than mass and thinking about cutoffs <br>
#
# denser grid <br>
#
#
# revisit big picture discussions: <br>
# idea - raw prediction for nucleation fraction as a function of stellar mass
# keep the shapes of all of these distributions fixed  <br>
# to match observations - if we only change core cusp, predicted vs observed nucleation fraction - 7.5, 8, 8.5, 9, 9.5 - <br>
# still open question of whether which time scale starts to dominate at 9 and above, tricky at 9, most mass comes from growth, might not want to use that data point -  <br>
#
# annual review - naidine   <br>
# probably katya paper 2023, <br>
# https://www.aanda.org/articles/aa/abs/2022/02/aa39778-20/aa39778-20.html <br>
# https://www.aanda.org/articles/aa/abs/2022/11/aa44932-22/aa44932-22.html <br>
#
# for formation of NCS mergers - Shaunaks paper  <br>
# Scotts paper  - GCs and NSC  <br>
# old tremain papers  <br>
# work our way there <br>
# shaunaks intro has a lot of them <br>
#
# screenshot paper ELVES II basically has the data <br>
#
# sanchzes jansesn papers <br>
#
# stats in virgo as good as its gonna be<br>
#
# scot tremains theses was where this eas first introdued<br>
#
# outline of introduction <br>
#
# NSC as a func of stellar mass <br>
#
# for publication, what would be a reasonable error bar <br>

# %% [markdown]
# ## DEC 26th w shaunak
#
# in big blobs what : <br>
# draw bin in that space - given stellar mass 10^8 what is prob that log re = 1 +- 0.??<br>
# and gc mass is smth += 0.1<br>
# cube of space,<br>
#
# count all points in that bin and devide by total number of bins
#
# probability of being in bin in the first 1	``place
#
# then look at corresponding cubde in nucleation <br>
# given that youre in that space here is the nucleation fraction<br>
# do that for all of them
#
# each point is 10 sims - are there any that half are nucleated and some are not
#
# color them if 1 out of 10. red if 2 out of 10
#
# take probability and multiply by fraction
#
# can try w 100 and 0 or actual probabilities
#
# formatting of latex doc - journal - astro -
#
#
#
# [3.2, 3.3, 3.4, 3.5, 3.6]
#
#
# What is the errorbar on that number?
#
#
# Fraction is a little low<br>
# Approach makes sense
#
# Want simulations on top of the data<br>
# nucleation frac as a function of mass<br>
# put simulated points on top of the data<br>
# load in a script for plotting <br>
# maybe in slack; best way to get an errorbar <br>
# shift the cloud by changing assumtions for the gc mass and see how much higher and lower our interpolation gets <br>
#
# Assumtion were making that globular clusters are distributed like stars today
#
# which parameters will make the biggest diff<br>
# probably gc mass
#
# this thurs and firday

# %% [markdown]
# ## DEC 27th
# Worth explaning how does the simulation pay out, assume radial distribution of a star cluster , dark matter halo has a small impact ….
#
# Give reader intuition for which parameters matter the most,
#
# show how the nucleation fraction is changing with diff params maybe at the end
#
# paragraph missing at the beggining of 2
#
# Here is how we implement the DF…,
#
# on more step to write about in methods which is an actual paragraph where we take fig 1 and 2 to put them togetehr to get nucleation frac …
#
# or maybe make that results
#
# maybe not full full explenation of pre JP <br>
# need to justify our criteria how we average in 10 iterations
#
# uncertainties subsection in results, simulation sensitivity t0 parameters, picl a fig that we have explored the param space
#
# fig 7 -
#
# typical gc is 10 times less massive than NSC so we need multiple GC mergers, maybe in 2.1; keep figure 6 in, not sure coz sersic index
#
# definition of nucleated paragraph somewhere
#
#
# results:<br>
# 2 subsections<br>
# 1. present the nucleation fraction as a func of stellar mass<br>
# 2. says smth about parameter sensitivity based on old runs, like fig 7 showing re sensitivity<br>
#
# nucleation fraction collapsed as a funtion of Re
#
# three mass bins how nucleation fractions change with Re - demonstarte paramtere sensitivity
#
# devide each mass bin into teo raddii, halo masses
#
# would help us with uncertainty - can read
#
# 2 bins in re, 2 bins, in halo, 2 in gc mass but as a function of stellar mass
#
# discussion is just gonna say what we can about core vs cusp  - if NCS frac is lower than observed, not much space for cores
#
# write out notes and figs and then she will look over,
